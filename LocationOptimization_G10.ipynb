# %%
# !pip install googlemaps
# !pip install polyline
# !pip install folium
# !pip install scipy
# !pip install pandas
# !pip install geopy

import pandas as pd
import math
import scipy.optimize as opt
from geopy.geocoders import GoogleV3
import googlemaps
import polyline
import folium

# Enter your own API key
geolocator = GoogleV3(api_key='')
gmaps = googlemaps.Client(key='')    # Initialize the Google Maps client with your API key
# Out:
# Requirement already satisfied: googlemaps in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (4.10.0)
# Requirement already satisfied: requests<3.0,>=2.20.0 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from googlemaps) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2023.11.17)
# Requirement already satisfied: polyline in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (2.0.1)
# Requirement already satisfied: folium in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (0.15.1)
# Requirement already satisfied: branca>=0.6.0 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from folium) (0.7.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from folium) (1.26.3)
# Requirement already satisfied: requests in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from folium) (2023.10.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from requests->folium) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from requests->folium) (2023.11.17)
# Requirement already satisfied: scipy in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (1.12.0)
# Requirement already satisfied: numpy<1.29.0,>=1.22.4 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from scipy) (1.26.3)
# Requirement already satisfied: pandas in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: geopy in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /Users/owdengodson/anaconda3/envs/baproject/lib/python3.9/site-packages (from geopy) (2.0)

# %%
# Define functions

# Function to get geocode for a location
def get_geocode(location):
    coords = geolocator.geocode(location)
    lat = round(coords.latitude, 4)
    lng = round(coords.longitude, 4)
    return lat, lng

# Great circle ("as crow flies") distance
def calc_dist_haversine(lat1, lng1, lat2, lng2):
  # Convert latitude and longitude from degrees to radians
  lat1, lng1, lat2, lng2 = map(math.radians, [lat1, lng1, lat2, lng2])

  a = math.sin((lat2 - lat1) / 2) ** 2 + math.cos(lat1) * math.cos(lat2) * math.sin((lng2 - lng1) / 2) ** 2
  dist_haversine_miles = 3959 * 2 * math.atan2(math.sqrt(a), math.sqrt(1 - a))

  return dist_haversine_miles

# Function to calculate Haversine distance from a point to locations in dataframe
def calc_cost_haversine(coords, data):
    lat, lon = coords
    distances = []
    for _, row in data.iterrows():
        distances.append(calc_dist_haversine(lat, lon, row['Lat'], row['Lng']))

    cost = (data['F'] * data['W'] * pd.Series(distances)).sum()
    return cost

# Function to calculate travel distance from origin to each destination
def calc_dist_driving(lat1, lng1, lat2, lng2):

    # Request directions and get travel distance and travel time
    directions = gmaps.directions( (lat1, lng1), (lat2, lng2), mode='driving', units='imperial')

    # dist_travel_text = directions[0]['legs'][0]['distance']['text']
    # dist_travel_kms  = (directions[0]['legs'][0]['distance']['value']) // 1000
    dist_travel_mile = (directions[0]['legs'][0]['distance']['value']) // 1609.344

    # travel_time_text = directions[0]['legs'][0]['duration']['text']
    # travel_time_mins = (directions[0]['legs'][0]['duration']['value']) // 60

    return dist_travel_mile

# Function to calculate Haversine distance from a point to locations in dataframe
def calc_cost_driving(coords, data):
    lat, lon = coords
    distances = []
    for _, row in data.iterrows():
        distances.append(calc_dist_driving(lat, lon, row['Lat'], row['Lng']))

    cost = (data['F'] * data['W'] * pd.Series(distances)).sum()
    return cost

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Function to get the content of the Wikipedia page
def get_wiki_page(url):
    response = requests.get(url)
    response.raise_for_status()
    return response.text

# Function to extract the latitude and longitude
def get_lat_lon(neighborhood_url):
    try:
        response = requests.get(neighborhood_url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        geo_tag = soup.find('span', {'class': 'geo'})
        if geo_tag:
            lat, lon = geo_tag.text.split('; ')
            return lat.strip(), lon.strip()
    except requests.RequestException:
        pass
    return None, None

# Function to extract the table and the corresponding neighborhood links
def parse_neighborhoods(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    table = soup.find('table', {'class': 'wikitable sortable'})
    neighborhoods = []

    for row in table.find_all('tr')[1:]:
        cols = row.find_all('td')
        name = cols[0].text.strip()
        population = cols[1].text.strip().replace(',', '')
        link = cols[0].find('a')
        lat, lon = (None, None)
        if link and 'href' in link.attrs:
            lat, lon = get_lat_lon('https://en.wikipedia.org' + link.attrs['href'])
        neighborhoods.append({'Location': name+", Atlanta, GA", 'F': 1, 'W': int(population), 'Lat': lat, 'Lng': lon})
    
    return neighborhoods

# Main script
wiki_url = 'https://en.wikipedia.org/wiki/Table_of_Atlanta_neighborhoods_by_population'
content = get_wiki_page(wiki_url)
neighborhood_data = parse_neighborhoods(content)

# Convert to DataFrame and sort by population
df_neighborhoods = pd.DataFrame(neighborhood_data)
df_top_neighborhoods = df_neighborhoods.sort_values(by='W', ascending=False).head(10)

# Reset index and display the DataFrame
df_top_neighborhoods.reset_index(drop=True, inplace=True)
print(df_top_neighborhoods)
# Out:
#                               Location  F      W         Lat          Lng
# 0                 Midtown, Atlanta, GA  1  16569  33.7868014  -84.3795169
# 1                Downtown, Atlanta, GA  1  13411    33.75500    -84.39000
# 2         Old Fourth Ward, Atlanta, GA  1  10505      33.766      -84.372
# 3          North Buckhead, Atlanta, GA  1   8270   33.865252   -84.368863
# 4              Pine Hills, Atlanta, GA  1   8033      33.837      -84.352
# 5  Morningside/Lenox Park, Atlanta, GA  1   8030   33.797519   -84.358295
# 6       Virginia-Highland, Atlanta, GA  1   7800  33.7824000  -84.3543000
# 7              Grant Park, Atlanta, GA  1   6771      33.736      -84.371
# 8            Georgia Tech, Atlanta, GA  1   6607      33.776      -84.396
# 9                Kirkwood, Atlanta, GA  1   5897   33.752095   -84.323668

# %%
df = df_top_neighborhoods
df_top_neighborhoods['Lat'] = pd.to_numeric(df_top_neighborhoods['Lat'], errors='coerce')
df_top_neighborhoods['Lng'] = pd.to_numeric(df_top_neighborhoods['Lng'], errors='coerce')

# Get geocodes for each address in the DataFrame
# df[['Lat', 'Lng']] = df['Location'].apply(lambda x: pd.Series(get_geocode(x)))

### Step 1: First we find optimal point using Haversine distance
# Initial guess for the optimization algorithm (somewhere close to the average of latitudes and longitudes)
initial_guess = [df['Lat'].mean(), df['Lng'].mean()]

# Extract min and max values of Latitude and Longitude columns for bounds
bounds = [(df['Lat'].min() - 5, df['Lat'].max() + 5), (df['Lng'].min() - 5, df['Lng'].max() + 5)]

# Minimize the total distance function using scipy's minimize
result = opt.minimize(calc_cost_haversine, initial_guess, args=(df,), method='SLSQP', bounds=bounds)

# Get the location address
result_address = gmaps.reverse_geocode((result.x))[0]['formatted_address']

print(f"\nMinimum cost and corresponding optimal location (lat, long): \n$ {(result.fun):,.2f}; { (result.x).round(4) }\nAddress: {result_address}")
# Out:
# Minimum cost and corresponding optimal location (lat, long):
# $ 198,323.66; [ 33.7819 -84.3746]
# Address: 10th St NE & Taft Ave NE, Atlanta, GA 30309, USA

# %%
### Step 2: Then we find driving distance using Google Maps Direction API

# Define ranges based on optimal point ± 0.5
diff = .02
ranges = (slice(int(result.x[0]) - diff, round(result.x[0], 0) + diff, 1),  slice(int(result.x[1]) - diff, round(result.x[1], 0) + diff, 1))

# Minimize the total distance function using scipy's integer minimizer
result_driving = opt.brute(calc_cost_driving, ranges, args=(df,), full_output=True, finish=None)
# Get the location address
result_driving_address = gmaps.reverse_geocode((result_driving[0]))[0]['formatted_address']

cost_haversine_driving = calc_cost_driving(result.x, df)
print(f"\nCost, Travel time using driving distance from point (lat, long) optimized using Haversine distance method : \n$ {cost_haversine_driving:,.2f}; { (result.x).round(4) }\nAddress: {result_address}")

print(f"\nMinimum cost, Travel time, and corresponding optimal location (lat, long): \n$ {result_driving[1]:,.2f}; { result_driving[0].tolist() }\nAddress: {result_driving_address}")
# Out:
# Cost, Travel time using driving distance from point (lat, long) optimized using Haversine distance method :
# $ 288,230.00; [ 33.7819 -84.3746]
# Address: 10th St NE & Taft Ave NE, Atlanta, GA 30309, USA
#
# Minimum cost, Travel time, and corresponding optimal location (lat, long):
# $ 2,624,476.00; [33.98, -84.02]
# Address: 1255 Watercrest Cir, Lawrenceville, GA 30043, USA

# %%
### Code to print locations on map

# Initialize the map centered around the mean of all locations
m = folium.Map(location = initial_guess, zoom_start=5)

# Add markers for optimal locations
folium.Marker(result.x, popup=result_address, icon=folium.Icon(color='orange')).add_to(m)           # Point using Haversine distnace
folium.Marker(result_driving[0], popup=result_driving_address, icon=folium.Icon(color='green')).add_to(m)     # Point using Driving distance

# Add links between locations
# for i in range(len(df['Location']) - 1):
#     start = tuple(result_driving[0])
#     end   = (df['Lat'][i], df['Lng'][i])
#     folium.PolyLine([loc1, loc2], color="blue", weight=2.5, opacity=1).add_to(m)

# Draw driving paths between locations
for i in range(len(df['Location'])):
    start = tuple(result_driving[0])
    end   = (df['Lat'][i], df['Lng'][i])

    # Add markers for locations from DataFrame
    folium.Marker([df['Lat'][i], df['Lng'][i]], popup=df['Location'][i]).add_to(m)
    # Get directions using Google Maps Directions API from optimal point to all locations
    directions = gmaps.directions(start, end, mode="driving")
    # Extract polyline points from API response and add to Folium map
    points = polyline.decode(directions[0]['overview_polyline']['points'])
    # Add driving path on the map
    folium.PolyLine(locations=points, color='blue', weight=5).add_to(m)

# Save the map as an HTML file
#m.save('C:\Temp\map_with_locations_and_paths.html')

print(f"\nCost, Travel time using driving distance from point (lat, long) optimized using Haversine distance method : \n$ {cost_haversine_driving:,.2f}; { (result.x).round(4) }\nAddress: {result_address}")
print(f"\nMinimum cost, Travel time, and corresponding optimal location (lat, long): \n$ {result_driving[1]:,.2f}; { result_driving[0].tolist() }\nAddress: {result_driving_address}")
# Out:
# Cost, Travel time using driving distance from point (lat, long) optimized using Haversine distance method :
# $ 288,230.00; [ 33.7819 -84.3746]
# Address: 10th St NE & Taft Ave NE, Atlanta, GA 30309, USA
#
# Minimum cost, Travel time, and corresponding optimal location (lat, long):
# $ 2,624,476.00; [33.98, -84.02]
# Address: 1255 Watercrest Cir, Lawrenceville, GA 30043, USA

# %%
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cabe9b5f3dac3d4083fbc2cc65a97ae9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cabe9b5f3dac3d4083fbc2cc65a97ae9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cabe9b5f3dac3d4083fbc2cc65a97ae9 = L.map(
#                 &quot;map_cabe9b5f3dac3d4083fbc2cc65a97ae9&quot;,
#                 {
#                     center: [33.78540674, -84.36656429],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f9a2eb9c5e6fd235eb723dfd8157e86 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2f9a2eb9c5e6fd235eb723dfd8157e86.addTo(map_cabe9b5f3dac3d4083fbc2cc65a97ae9);
#
#
#             var marker_062bfd047fc21231a47f7cbd686aa434 = L.marker(
#                 [33.781947622541324, -84.37455809934332],
#                 {}
#             ).addTo(map_cabe9b5f3dac3d4083fbc2cc65a97ae9);
#
#
#             var icon_09670e4208bcfb7e40b1ebeffbf5a137 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_062bfd047fc21231a47f7cbd686aa434.setIcon(icon_09670e4208bcfb7e40b1ebeffbf5a137);
#
#
#         var popup_78153e08b2b202b2111a486bb83a0ce1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fc8ef94ec6eeaecaa712693db90c103e = $(`&lt;div id=&quot;html_fc8ef94ec6eeaecaa712693db90c103e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;10th St NE &amp; Taft Ave NE, Atlanta, GA 30309, USA&lt;/div&gt;`)[0];
#                 popup_78153e08b2b202b2111a486bb83a0ce1.setContent(html_fc8ef94ec6eeaecaa712693db90c103e);
#
#
#
#         marker_062bfd047fc21231a47f7cbd686aa434.bindPopup(popup_78153e08b2b202b2111a486bb83a0ce1)
#         ;
#
#
#
#
#             var marker_b13078ff49fa9b942b7c3022360de9bd = L.marker(
#                 [33.98, -84.02],
#                 {}
#             ).addTo(map_cabe9b5f3dac3d4083fbc2cc65a97ae9);
#
#
#             var icon_e27459ecd4d440bccaad7d2f425f0bab = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b13078ff49fa9b942b7c3022360de9bd.setIcon(icon_e27459ecd4d440bccaad7d2f425f0bab);
#
#
#         var popup_0dfe6081d7c755c4d68921daa1c034a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e3f5de2e7db4a2bd56b675017a6e54b = $(`&lt;div id=&quot;html_3e3f5de2e7db4a2bd56b675017a6e54b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1255 Watercrest Cir, Lawrenceville, GA 30043, USA&lt;/div&gt;`)[0];
#                 popup_0dfe6081d7c755c4d68921daa1c034a2.setContent(html_3e3f5de2e7db4a2bd56b675017a6e54b);
#
#
#
#         marker_b13078ff49fa9b942b7c3022360de9bd.bindPopup(popup_0dfe6081d7c755c4d68921daa1c034a2)
#         ;
#
#
#
#
#             var marker_b7c54d5e904f67e08372cc205d8c62a7 = L.marker(
#                 [33.7868014, -84.3795169],
#                 {}
#             ).addTo(map_cabe9b5f3dac3d4083fbc2cc65a97ae9);
#
#
#         var popup_d5a6446696690918533b7fc4bb27dcbe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8169bbf7f39e95d62b6bf81a3182c4fd = $(`&lt;div id=&quot;html_8169bbf7f39e95d62b6bf81a3182c4fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Midtown, Atlanta, GA&lt;/div&gt;`)[0];
#                 popup_d5a6446696690918533b7fc4bb27dcbe.setContent(html_8169bbf7f39e95d62b6bf81a3182c4fd);
#
#
#
#         marker_b7c54d5e904f67e08372cc205d8c62a7.bindPopup(popup_d5a6446696690918533b7fc4bb27dcbe)
#         ;
#
#
#
#
#             var poly_line_ef5d94d3d839e074a93012ceef26ad2f = L.polyline(
#                 [[33.98011, -84.02001], [33.98006, -84.0203], [33.98004, -84.02044], [33.97987, -84.02041], [33.97911, -84.02027], [33.97858, -84.02021], [33.97786, -84.02013], [33.97689, -84.02003], [33.97607, -84.01984], [33.97578, -84.01973], [33.97387, -84.01886], [33.97318, -84.01859], [33.97221, -84.01829], [33.97185, -84.01821], [33.97145, -84.01823], [33.97119, -84.01828], [33.97072, -84.01853], [33.97032, -84.01891], [33.97013, -84.01921], [33.96987, -84.01981], [33.96952, -84.02086], [33.96939, -84.02124], [33.96921, -84.02165], [33.96903, -84.02193], [33.96867, -84.0223], [33.96823, -84.02259], [33.9676, -84.02292], [33.96748, -84.02248], [33.96736, -84.02181], [33.9673, -84.02121], [33.967
